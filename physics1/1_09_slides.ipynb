# %% [markdown]
# <img src="../img/Signet_FNW_1.svg" alt="OVGU_FNW_Logo" width="300" align="right">
#
# # 1.9. Oscillations
#
# `ms06`
#
# **What is the purpose of the mechanism?**

# %% [markdown]
# $\Rightarrow$ Escapement with pendulum as found in mechanical clocks
#
# $\Rightarrow$ To understand the mechanism we need to **study oscillations** and **simple harmonic motion**

# %% [markdown]
# ## Simple Harmonic Motion — Motivation \& Notation
#
# `ms07 - Verschiedene Schwinger`
#
# - Many oscillatory systems (springs, pendulums, etc.) share the same mathematical structure  $\Rightarrow$ **simple harmonic motion (SHM)**
#
# - Displacement from equilibrium: $x(t)$
# - Velocity: $\dot x = \dfrac{dx}{dt}$
# - Acceleration: $\ddot x = \dfrac{d^2x}{dt^2}$

# %% [markdown]
# ## Horizontal Mass–Spring System — Model and Equation
#
# - Ideal mass–spring system on a frictionless horizontal surface
# - Spring force obeys Hooke’s law: $F=-kx$
# - Newton’s second law:
#   $$
#   m a = m\ddot x = -kx
#   $$
# - Equation of motion:
#   $$
#   \ddot x = - \frac{k}{m}x \quad \Leftrightarrow \quad \ddot x + \frac{k}{m}x = 0
#   $$
#
# - The equation already shows the key SHM feature:
#   - acceleration proportional to displacement
#   - acceleration opposite in direction
#
# <img src="../img/from_wiki/Harmonic_oscillator.svg" alt="Harmonic_oscillator.svg" width="200"/>
#
# *<sub>from [wikipedia](https://en.wikipedia.org/wiki/File:Harmonic_oscillator.svg), public domain</sub>*

# %% [markdown]
# ## Horizontal Mass–Spring System — What a Solution Must Do \& Guessing it
#
# - We seek a function $x(t)$ that satisfies the equation $\ddot x + \frac{k}{m}x = 0$ for **all times**
# $\Rightarrow$ Any valid solution must cancel the explicit time dependence when inserted
#
# - Motion swings repeatedly between two extreme positions
# $\Rightarrow$ **Trigonometric** functions naturally describe oscillations
# $\Rightarrow$ Mass release at maximum displacement $x_0$ $\rightarrow$ use **cosine**
#
# - **Solution Guess**:
#   $$
#   x(t)=x_0\cos(\omega t)
#   $$
# - **Angular frequency** $\omega$ controls how fast the motion evolves in time
# - Since $\cos$ repeats every $2\pi$, period $T$ defined as $T=\frac{2\pi}{\omega}$
#
#
#
# <img src="../img/from_wiki/Simple_harmonic_motion_animation.gif" alt="Simple_harmonic_motion_animation.gif" width="300"/>
#
# *<sub>from [wikipedia](https://en.wikipedia.org/wiki/File:Simple_harmonic_motion_animation.gif), public domain</sub>*

# %% [markdown]
# ## Horizontal Mass–Spring System — Time Derivatives
#
# - Solution guess (displacement):
#   $$
#   x(t)=x_0\cos(\omega t)
#   $$
# - First derivative (velocity):
#   $$
#   \dot x(t)=-x_0\omega\sin(\omega t)
#   $$
# - Second derivative (acceleration):
#   $$
#   \ddot x(t)=-x_0\omega^2\cos(\omega t)
#   $$

# %% [markdown]
# ## Horizontal Mass–Spring System — Inserting the Guess
#
# - Substitute into
#   $$
#   \ddot x+\frac{k}{m}x=0
#   $$
# - This gives
#   $$
#   -x_0\omega^2\cos(\omega t)+\frac{k}{m}x_0\cos(\omega t)=0
#   $$
# - Common factor $\cos(\omega t)$ cancels
# - Remaining condition:
#   $$
#   -\omega^2+\frac{k}{m}=0
#   $$

# %% [markdown]
# ## Horizontal Mass–Spring System — Result
#
# - Cancellation for all times requires:
#   $$
#   \omega^2=\frac{k}{m}
#   $$
# - Solution:
#   $$
#   x(t)=x_0\cos(\omega t), \qquad \omega=\sqrt{\frac{k}{m}}
#   $$
# - Period of oscillation:
#   $$
#   T=\frac{2\pi}{\omega}=2\pi\sqrt{\frac{m}{k}}
#   $$
# - Period depends only on mass and spring constant, not on amplitude

# %% [markdown]
# ## Vertical Mass–Spring System — Equilibrium Shift
#
# `ms07 - Verschiedene Schwinger`
#
# - Forces are weight $mg$ and spring force $-kx$, thus Newton’s second law:
#   $$
#   m\ddot x = mg - kx
#   $$
# - Equilibrium **after** mass placed on spring ($\ddot x = 0$):
#   $$mg = kx_0 \; \Leftrightarrow \;  x_0=\frac{mg}{k}$$
#   $\Rightarrow$ $x_0$ is the static extension due to the mass’s weight
# - Total extension of spring $x_0 + x$ gives
#   $$
#   m\ddot x = mg - k(x_0 + x) = mg - mg - kx  = - kx
#   $$
#   $\Rightarrow$ Redefine $x(t)$ as displacement **from equilibrium** removes the constant gravity term from the motion

# %% [markdown]
# ## Vertical Mass–Spring System — Oscillation Equation
#
#   $$
#   m\ddot x=-kx
#   \quad\Rightarrow\quad
#   \ddot x+\frac{k}{m}x=0
#   $$
# - Same equation as the horizontal system
#
# - Cosine solution:
#   $$
#   x(t)=x_0\cos(\omega t), \qquad \omega^2=\frac{k}{m}
#   $$
# - Period:
#   $$
#   T=2\pi\sqrt{\frac{m}{k}}
#   $$
#
# - Gravity shifts equilibrium but does **not** change the period

# %% [markdown]
# ## Simple Harmonic Motion (SHM) — General Form
#
# - **Simple harmonic motion (SHM)** not limited to spring but applied whenever
#   $$
#   \ddot x + \omega^2 x = 0
#   \quad\Leftrightarrow\quad
#   \ddot x = -\omega^2 x
#   $$
# - Acceleration is proportional to displacement and always directed toward equilibrium
# - **Harmonic** means: sinusoidal, single-frequency motion from a linear restoring mechanism
# - General solution:
#   $$
#   x(t)=A\cos(\omega t+\phi)
#   $$
#     - with $A$ as the amplitude
#     - with **phase constant** $\phi$ to capture different initial positions and velocities
#     - with $\omega$ as the **angular eigenfrequency** (natural frequency)
#     - with period $T=\frac{2\pi}{\omega}$
#
#
# - Note: equivalently $A\sin(\omega t+\phi)$; sine and cosine differ only by a phase shift

# %% [markdown]
# ## Mathematical Pendulum — Assumptions \& Restoring Force
#
# `ms18 - Schwingungsdauer bestimmen - Lichtschranke`
#
# - **Assumptions**: Point mass on a massless, inextensible string of length $L$, only small angular displacements, no friction
# - Restoring force (tangential component of weight $mg$):
#   $$
#   F_{\text{r}}=-mg\sin\theta
#   $$
#   $\Rightarrow$ Minus sign: force always points toward equilibrium
#
#
# <img src="../img/from_wiki/Simple_gravity_pendulum.svg" alt="Simple_gravity_pendulum.svg" width="350"/>
# <img src="../img/from_wiki/Pendulum_gravity.svg" alt="Pendulum_gravity.svg" width="200"/>
#
# *<sub>[left] from [wikipedia](https://en.wikipedia.org/wiki/File:Simple_gravity_pendulum.svg), public domain;
# [right] from [wikipedia](https://en.wikipedia.org/wiki/File:Pendulum_gravity.svg), [Attribution-Share Alike 3.0 Unported](//creativecommons.org/licenses/by-sa/3.0/deed.en)</sub>*

# %% [markdown]
# ## Mathematical Pendulum — Small-Angle Approximation \& Newton’s Law
#
# - For small angles (in radians):
#   $$
#   \sin\theta \approx \theta
#   $$
# - Restoring force becomes linear:
#   $$
#   F_{\text{r}}\approx -mg\,\theta
#   $$
#
# - Newton’s second law (tangential direction) with $a_{\text{t}}=L\alpha=L\ddot\theta$:
#   $$
#   m a_{\text{t}} = m L \ddot\theta = -mg\,\theta = F_{\text{r}}
#   $$
#
# <img src="../img/from_wiki/Small-angle_approximation_for_sine_function.svg" alt="Small-angle_approximation_for_sine_function.svg" width="250"/>
#
# *<sub>from [wikipedia](https://commons.wikimedia.org/wiki/File:Small-angle_approximation_for_sine_function.svg), [CC0 1.0 Universal](https://creativecommons.org/publicdomain/zero/1.0/deed.en)</sub>*

# %% [markdown]
# ## Mathematical Pendulum — Equation of Motion \& Initial Guess
#
# $$
#   mL\ddot\theta=-mg\,\theta
# $$
# $$
#   \ddot\theta+\frac{g}{L}\theta=0
# $$
# $\Rightarrow$ This is the standard equation of **simple harmonic motion**
#
# Solution guess with $\theta_0$ as maximum angular displacement:
#   $$
#   \theta(t)=\theta_0\cos(\omega t+\phi)
#   $$

# %% [markdown]
# ## Mathematical Pendulum — Determining $\omega$ and the Period
#
# - Derivatives:
#   $$
#   \dot\theta=-\theta_0\omega\sin(\omega t+\phi), \qquad
#   \ddot\theta=-\theta_0\omega^2\cos(\omega t+\phi)
#   $$
#
# - Insert into the equation of motion:
#   $$
#   -\theta_0\omega^2\cos(\omega t+\phi)+\frac{g}{L}\theta_0\cos(\omega t+\phi)=0
#   $$
#
# - Time dependence cancels for all $t$ if
#   $$
#   \omega^2=\frac{g}{L}
#   $$
#
# - Angular eigenfrequency, period and frequency ($f = \tfrac1T = \tfrac{\omega}{2\pi}$):
#   $$
#   \omega=\sqrt{\frac{g}{L}}, \quad T=2\pi\sqrt{\frac{L}{g}}, \qquad f=\frac{1}{2\pi}\sqrt{\frac{g}{L}}
#   $$
#   $\Rightarrow$ Period depends only on $L$ and $g$, **not on mass or amplitude**

# %% [markdown]
# ## Other Pendulums — Examples
#
# `ms07 - Verschiedene Schwinger`
#
#
# | Feature | **Physical Pendulum** | **Torsion Pendulum** |
# |---|---|---|
# | Key difference to mathematical pendulum | Mass **distributed** in a rigid body | No gravity-driven swing, **twisting** motion |
# | Restoring mechanism | Gravity acting on center of mass | Elastic torsion of a wire/fiber |
# | Newton’s law used | Rotational: $I\ddot\theta=\tau\approx- mgd\,\theta$ | Rotational: $I\ddot\theta=\tau=-\kappa\theta$ |
# | Equation of motion | $\ddot\theta+\dfrac{mgd}{I}\theta=0$ | $\ddot\theta+\dfrac{\kappa}{I}\theta=0$ |
# | Angular frequency \& period | $\omega=\sqrt{\dfrac{mgd}{I}}$ & $T=2\pi\sqrt{\dfrac{I}{mgd}}$ | $\omega=\sqrt{\dfrac{\kappa}{I}}$ & $T=2\pi\sqrt{\dfrac{I}{\kappa}}$|
# | Reduced / equivalent length | $L_{\text{eq}}=\dfrac{I}{md}$ | not applicable |

# %% [markdown]
# ## Other Pendulums — Examples (cont')
#
# `ms07 - Schwinger mit Fluid `
#
#
# <img src="../img/from_wiki/Taipei_101_Tuned_Mass_Damper_2010.jpg" alt="Taipei_101_Tuned_Mass_Damper_2010.jpg" width="400"/>
# <img src="../img/from_wiki/Taipei_101_Tuned_Mass_Damper.png" alt="Taipei_101_Tuned_Mass_Damper.png" width="450"/>
#
# *<sub>[left] from [wikipedia](https://en.wikipedia.org/wiki/File:Taipei_101_Tuned_Mass_Damper_2010.jpg), [Attribution-Share Alike 3.0 Unported](//creativecommons.org/licenses/by-sa/3.0/deed.en)
# [right] from [wikipedia](https://en.wikipedia.org/wiki/File:Taipei_101_Tuned_Mass_Damper.png), [Attribution-Share Alike 4.0 International](//creativecommons.org/licenses/by-sa/4.0/deed.en)</sub>*

# %% [markdown]
# ## SHM as Projection of Uniform Circular Motion
#
# `ms35 - Projektion einer Kreisbewegung`
#
# - Simple harmonic motion can be viewed as the **projection of uniform circular motion** onto a straight line
# - This geometric picture explains amplitude, phase, angular frequency, and phase relations
# - Angular position for a point moving on a circle of radius $r_0$ with constant angular speed $\omega$
#   $$
#   \theta(t)=\omega t+\phi
#   $$
# - Cartesian coordinates of the circular motion:
#   $$
#   x(t)=r_0\cos(\omega t+\phi), \qquad y(t)=r_0\sin(\omega t+\phi)
#   $$
#     $\Rightarrow$ These are the SHM solutions for projections on the x- and y-axis, respectively
#
#
#   <img src="../img/from_wiki/Sine_and_cosine_animation.gif" alt="Sine_and_cosine_animation.gif" width="300"/>
#
# *<sub>from [wikipedia](https://en.wikipedia.org/wiki/File:Sine_and_cosine_animation.gif), [CC0 1.0 Universal](https://creativecommons.org/publicdomain/zero/1.0/deed.en)</sub>*

# %% [markdown]
# ## Damped Harmonic Motion — Motivation \& Model
#
# `ms07 - Verschiedene Schwinger`
#
# - Real oscillators lose energy due to friction, air resistance, internal dissipation, etc.
# - Amplitude decreases with time $\rightarrow$ **damped harmonic motion**
# - Linear damping model:
#   $$
#   F_{\text{damp}} = -b\,\dot x
#   $$
# - Mass–spring system:
#   $$
#   F = -kx - b\,\dot x
#   $$
# - Newton’s second law:
#   $$
#   m\ddot x + b\dot x + kx = 0
#   $$

# %% [markdown]
# ## Damped Harmonic Motion — Motivated Ansatz
#
# - Undamped case: cosine motion between two turning points
# - Weak damping should:
#   - keep oscillatory behavior
#   - slowly reduce amplitude
# - Simplest model: oscillation × exponential decay
# - **Ansatz**:
#   $$
#   x(t) = x_0\,e^{-\gamma t}\cos(\omega t)
#   $$
# - $\gamma$ controls amplitude decay, $\omega$ is modified oscillation frequency
#
# <img src="../img/from_wiki/Damped_oscillation_graph2.svg" alt="Damped_oscillation_graph2.svg" width="250"/>
#
# *<sub>from [wikipedia](https://de.wikipedia.org/wiki/Datei:Damped_oscillation_graph2.svg) by Jahobr, gemeinfrei</sub>*

# %% [markdown]
# ## Damped Harmonic Motion — Derivatives (Result)
#
# - First derivative:
#   $$
#   \dot x = x_0 e^{-\gamma t}\big(-\gamma\cos(\omega t)-\omega\sin(\omega t)\big)
#   $$
# - Second derivative:
#   $$
#   \ddot x
#   = x_0 e^{-\gamma t}\big((\gamma^2-\omega^2)\cos(\omega t)
#   +2\gamma\omega\sin(\omega t)\big)
#   $$

# %% [markdown]
# ## Damped Harmonic Motion — Inserting into the ODE
#
# - Insert $\dot x$ and $\ddot x$ into
#   $$
#   m\ddot x + b\dot x + kx = 0
#   $$
# - After collecting terms:
#   $$
#   x_0 e^{-\gamma t}
#   \Big[
#   (m(\gamma^2-\omega^2)-b\gamma+k)\cos(\omega t)
#   +(2m\gamma\omega-b\omega)\sin(\omega t)
#   \Big]=0
#   $$
# - Time dependence cancels only if **both coefficients vanish**

# %% [markdown]
# ## Damped Harmonic Motion — Damping Constant
# - Time dependence cancels only if **both coefficients vanish**
#   $$
#   x_0 e^{-\gamma t}
#   \Big[
#   (m(\gamma^2-\omega^2)-b\gamma+k)\cos(\omega t)
#   +(2m\gamma\omega-b\omega)\sin(\omega t)
#   \Big]=0
#   $$
#
# - From the sine term:
#   $$
#   2m\gamma\omega - b\omega = 0
#   $$
# - Non-trivial motion requires $\omega\neq0$
# - Result:
#   $$
#   \gamma = \frac{b}{2m}
#   $$

# %% [markdown]
# ## Damped Harmonic Motion — Frequency Shift
# - Time dependence cancels only if **both coefficients vanish**
#   $$
#   x_0 e^{-\gamma t}
#   \Big[
#   (m(\gamma^2-\omega^2)-b\gamma+k)\cos(\omega t)
#   +(2m\gamma\omega-b\omega)\sin(\omega t)
#   \Big]=0
#   $$
#
# - From the cosine term:
#   $$
#   m(\gamma^2-\omega^2)-b\gamma+k=0
#   $$
# - Using $\gamma=\tfrac{b}{2m} \; \leftrightarrow \; \tfrac{b}{m} = 2 \gamma$:
#   $$
#   (\gamma^2-\omega^2)-\frac{b}{m}\gamma+\frac{k}{m}=0
#   $$
#   $$
#   \omega^2 = \frac{k}{m}-\gamma^2
#   $$
# - With undamped eigenfrequency $\omega_0^2=\tfrac{k}{m}$, final result:
#   $$
#   \omega=\sqrt{\omega_0^2-\gamma^2}
#   $$

# %% [markdown]
# ## Damped Harmonic Motion — Underdamped Case
#
# - Condition:
#   $$
#   \gamma<\omega_0
#   $$
# - Oscillatory motion with decaying amplitude:
#   $$
#   x(t)=x_0 e^{-\gamma t}\cos(\omega t)
#   $$
# - Energy decay:
#   $$
#   E(t)=E_0 e^{-2\gamma t}
#   $$

# %% [markdown]
# ## Damped Harmonic Motion — Critical Damping
#
# - Boundary case:
#   $$
#   \gamma=\omega_0
#   $$
# - Fastest return to equilibrium **without oscillation**
# - Solution form ($C_1$ and $C_2$ determined from initial conditions):
#   $$
#   x(t)=(C_1+C_2 t)e^{-\gamma t}
#   $$
# - Important in e.g. analogue measurement instruments and shock absorbers

# %% [markdown]
# ## Damped Harmonic Motion — Overdamped Case
#
# - Strong damping:
#   $$
#   \gamma>\omega_0
#   $$
# - No oscillations
# - Two exponential decay modes:
#   $$
#   x(t)=C_1 e^{-(\gamma+\sqrt{\gamma^2-\omega_0^2})t}
#        +C_2 e^{-(\gamma-\sqrt{\gamma^2-\omega_0^2})t}
#   $$
# - Typically: fast initial decay + slow long-time relaxation

# %% [markdown]
# ## Damped Harmonic Motion — Summary
#
# - Damping introduces energy loss and amplitude decay
# - Equation:
#   $$
#   m\ddot x+b\dot x+kx=0
#   $$
# - Key parameters:
#   $$
#   \gamma=\frac{b}{2m},\qquad
#   \omega=\sqrt{\omega_0^2-\gamma^2}
#   $$
# - Three regimes:underdamped (oscillatory), critically damped (fastest non-oscillatory), \& overdamped (slow, monotonic)
# - Realistic extension of ideal SHM
#
# <img src="../img/from_wiki/Federpendel_verschiedene_Daempfungen.gif" alt="Federpendel_verschiedene_Daempfungen.gif" width="400"/>
# <img src="../img/from_wiki/Damped_oscillations.gif" alt="Damped_oscillations.gif" width="300"/>
#
# *<sub>[left] from [wikipedia](https://de.wikipedia.org/wiki/Datei:Federpendel_verschiedene_D%C3%A4mpfungen.gif), [Attribution-Share Alike 4.0 International](//creativecommons.org/licenses/by-sa/4.0/deed.de)
# [right] from [wikipedia](https://en.wikipedia.org/wiki/File:Damped_oscillations.gif), License: public domain</sub>*

# %% [markdown]
# ## Forced Oscillations — Motivation and Model
#
# `ms15 - Schwingender Motor`
#
# - Real systems are often driven by a **periodic external force**
# - Energy input competes with damping $\rightarrow$ **forced oscillations** and **resonance**
# - Sinusoidal driving force:
#   $$
#   F(t)=F_0\cos(\omega_d t)
#   $$
# - Equation of motion:
#   $$
#   m\ddot x+b\dot x+kx=F_0\cos(\omega_d t)
#   $$

# %% [markdown]
# ## Forced Oscillations — Steady-State Response
#
# - Initial motion depends on initial conditions and decays with damping
# - Long-term motion is maintained by the driving force
# - **Steady-state ansatz** (same frequency as driving force):
#   $$
#   x(t)=A\cos(\omega_d t-\delta)
#   $$
#   $\Rightarrow$ System oscillates at the **driving frequency** $\omega_d$ and with phase offset $\delta$

# %% [markdown]
# ## Forced Oscillations — Amplitude Response
#
# - Solving the equation yields the amplitude:
#   $$
#   A=\frac{F_0/m}{\sqrt{(\omega_0^2-\omega_d^2)^2+(2\gamma\omega_d)^2}}
#   $$
#   with
#   $$
#   \omega_0=\sqrt{\frac{k}{m}},\qquad \gamma=\frac{b}{2m}
#   $$
# - Amplitude depends strongly on the driving frequency

# %% [markdown]
# ## Resonance — Resonance
#
# `ms20 - Resonanz zwischen Motor und Pendeln verschiedener Länge`
#
# - Energy input balances dissipation $\rightarrow$ large amplitudes for weak damping
# - Maximum amplitude at resonance:
#   $$
#   A(\omega_r)\approx\frac{F_0/m}{2\gamma\omega_0}
#   $$
#
#
# - **Quality factor** measures resonance sharpness:
#   $$
#   Q=\frac{\omega_0}{2\gamma}
#   $$
#
# <img src="../img/from_wiki/Mplwp_resonance_zeta_envelope.svg" alt="Mplwp_resonance_zeta_envelope.svg" width="350"/>
#
# *<sub>from [wikipedia](https://en.wikipedia.org/wiki/File:Mplwp_resonance_zeta_envelope.svg), [GNU Free Documentation License](https://en.wikipedia.org/wiki/en:GNU_Free_Documentation_License)*

# %% [markdown]
# <img src="../img/Signet_FNW_1.svg" alt="OVGU_FNW_Logo" width="300" align="right">
#
# ## Revisit initial experiment: Escapement, oscillations, \& clocks
#
# `ms06`
#
# - weight provides (potential) energy to drive machine
# - via escapement, a defined impulse to the pendulum $\rightarrow$ **forced oscillation**
# - pendulum length determines period, i.e. $T=1\text{s}$, and releases escapement for next step (lowering of mass and subsequent new impulse)
# - add gears to build proper clock
