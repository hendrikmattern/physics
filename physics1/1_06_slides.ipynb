# %% [markdown]
# <img src="../img/Signet_FNW_1.svg" alt="OVGU_FNW_Logo" width="300" align="right">
#
# # 1.6. Rotational dynamics \& angular momentum
#
# `mk15`
#
# **Which egg is cooked? How to check?**

# %% [markdown]
# ## Mass vs. mass distribution?
#
# `mk14 - Abrollen versch. Körper`
#
# **Which body is the fastest \& why?**

# %% [markdown]
# - Study rotational motion
# - Introduce **torque, moment of inertia,** \& **angular momentum**
# - New concepts of **rotational kinetic energy** \& **angular momentum conservation**

# %% [markdown]
# ## Recap \& Primer Rotational Motion
#
# - The position on the circle is described by the **angular displacement** $ \phi(t)$ (in radians) measured from the $+x$-axis
# - **Angular velocity** $ \omega$ is measured in **rad/s** and **angular acceleration** $ \alpha$ in **rad/s²**:
#   $$
#   \omega = \frac{d \phi}{dt}, \qquad  \alpha = \frac{d \omega}{dt} = \frac{d^2 \phi}{dt^2}
#   $$
#
# - Linear quantities from angular ones:
# $$s = r\phi, \quad v = r\omega, \quad a_t = r\alpha, \quad a_r = \tfrac{v}{r^2}= r\omega^2$$
#
# - **Key idea**: Angular motion is identical for all points,linear motion scales with radius $r$.

# %% [markdown]
# ## Angular motion with vectors
#
# **Question**: Linear quantities are **vectors**? What about angular ones?
#
# * $\vec s, \vec v, \vec a_t$ all tangential
# * position vector $\vec r$ and $\vec a_r$ radially

# %% [markdown]
# * $\Rightarrow$ $\vec \phi, \vec \omega, \vec \alpha$ oriented along rotation axis $\Leftrightarrow$ they **define the axis of rotation**
# * **direction** (positive vs. negative) determined by **Right-Hand Rule** (a.k.a. convention)
#
# <img src="../img/from_wiki/350px-Right-hand_grip_rule.svg.png" alt="RHR-1" width="150"/>
# <img src="../img/from_wiki/Vector-omega.svg" alt="Vector-omega.svg" width="225"/>
#
#
# *<sub>[left] from [wikipedia](https://en.wikipedia.org/wiki/File:Right-hand_grip_rule.svg), public domain;
# [right] from [wikipedia](https://en.wikipedia.org/wiki/File:Vector-omega.svg), [CC0 1.0 Universal](https://creativecommons.org/publicdomain/zero/1.0/deed.en)</sub>*

# %% [markdown]
# ## Angular motion with vectors (cont')
#
# **Cross product** relates angular and linear quantities, e.g.
#
# $$\vec v = \vec \omega \times \vec r $$
#
# Key properties:
# $$\vec v \perp (\vec \omega \times \vec r)$$
# $$ \vec \omega \times \vec r = - \vec r \times \vec \omega $$
#
# <img src="../img/from_wiki/Cross_product_vector.svg" alt="Cross_product_vector.svg" width="100"/>
# <img src="../img/from_wiki/Right_hand_rule_cross_product.svg" alt="Right_hand_rule_cross_product.svg" width="225"/>
#
# *<sub>[left] from [wikipedia](https://en.wikipedia.org/wiki/File:Cross_product_vector.svg), public domain;
# [right] from [wikipedia](https://en.wikipedia.org/wiki/File:Right_hand_rule_cross_product.svg), [Attribution-Share Alike 3.0 Unported](//creativecommons.org/licenses/by-sa/3.0/deed.en)</sub>*

# %% [markdown]
# # Side note: Pseudovectors
#
# * $\vec \phi, \vec \omega, \vec \alpha$ are pseudovectors, also called axial vectors
# * Under reflection, pseudovectors **do not flip sign**
# * Imagine doing the right-hand-rule in front of a mirror
# * Pseudovectors are relevant e.g. for symmetry-based solutions in physics
#
# <img src="../img/from_wiki/Impulsmoment_van_autowiel_onder_inversie.svg" alt="Impulsmoment_van_autowiel_onder_inversie.svg" width="300"/>
#
# *<sub>from [wikipedia](https://en.wikipedia.org/wiki/File:Impulsmoment_van_autowiel_onder_inversie.svg), [Attribution-Share Alike 3.0 Unported](//creativecommons.org/licenses/by-sa/3.0/nl/deed.en)</sub>*

# %% [markdown]
# ## Revisit acceleration $\vec a$ for circular motion
#
#
#
# - To compute linear acceleration:
#   $$
#   \vec{a} = \frac{d\vec v}{dt} = \frac{d(\vec{\omega} \times \vec{r})}{dt}
#   $$
#
# - Use **vector product rule**:
#   $$
#   \frac{d}{dt}(\vec{A} \times \vec{B})
#   = \frac{d\vec{A}}{dt} \times \vec{B}
#     + \vec{A} \times \frac{d\vec{B}}{dt}
#   $$

# %% [markdown]
# - Apply to $\vec{\omega}$ and $\vec{r}$:
#   $$
#   \vec{a} = \frac{d}{dt}(\vec{\omega} \times \vec{r})
#   = \frac{d\vec{\omega}}{dt} \times \vec{r}
#     + \vec{\omega} \times \frac{d\vec{r}}{dt}
#   $$

# %% [markdown]
# ## Revisit acceleration $\vec a$ for circular motion (cont')
#
#
# **Substitute** $\frac{d\vec{\omega}}{dt} = \vec{\alpha}$, \& $\frac{d\vec{r}}{dt} = \vec{v} = \vec{\omega} \times \vec{r}$
#
#   $$
#   \vec{a}
#   = \vec{\alpha} \times \vec{r}
#   + \vec{\omega} \times (\vec{\omega} \times \vec{r})
#   = \vec{a_t} + \vec{a_R}
#   $$
#
# **Tangential:**
# $$\vec{a_t} = \vec{\alpha} \times \vec{r} $$
#
# **Radial (centripetal):**
# $$\vec{a_R} = \vec{\omega} \times (\vec{\omega} \times \vec{r})$$
#
# (note relation to magnitude of $a_R = \tfrac{v^2}{r} = \omega^2 r$ )

# %% [markdown]
# ## Accelerated circular motion
# `mk23 - accelerated circular motion`
#
# **What causes the angular acceleration?**

# %% [markdown]
# ## Accelerated circular motion (cont')
# `mk02 - Drehmoment`
#
# **What (else) causes the angular acceleration?**

# %% [markdown]
# ## Torque
#
# - Linear motion: force causes acceleration ($F = ma$)
# - Rotational motion: effectiveness of a force depends on **magnitude**, **angle**, and **where** it is applied
#
# - Torque:
#   $$
#   \vec{\tau} = \vec{r} \times \vec{F}
#   $$
# - Rotational analogue of force and measured in $\text N \cdot \text m$
# - Direction:
#     - Perpendicular to the plane of $\vec{r}$ and $\vec{F}$
#     - Set by **right-hand rule**
#     - CCW → out of page ⊙, CW → into page ⊗

# %% [markdown]
# ## Torque Magnitude
# `sim - Torque`
#
# - Torque magnitude:
#   $$
#   \tau = rF\sin\phi = r_\perp F = r F_\perp
#   $$
#   $\rightarrow$ Maximal when $\vec{F} \perp \vec{r}$; zero when $\vec{F} \parallel \vec{r}$
#
# - Lever arm (moment arm) $r_\perp = r\sin\phi$ $\rightarrow$ only the **perpendicular** component of the force causes rotation.
#
# <img src="../img/from_wiki/Moment_arm.svg" alt="Moment_arm.svg" width="300"/>
#
# *<sub>from [wikipedia](https://en.wikipedia.org/wiki/File:Moment_arm.svg), [CC0 1.0 Universal](https://creativecommons.org/publicdomain/zero/1.0/deed.en)</sub>*

# %% [markdown]
# ## Connection to Newton’s second law:
#   $$
#   \vec{F} = m\vec{a}, \qquad
#   \vec{\tau} = \vec{r} \times \vec{F}
#   $$
#
# **What component of $\vec a$ is relevant for torque?**

# %% [markdown]
# $\rightarrow$ Tangential acceleration $a_t = r\alpha$
#
# Because $\vec a_t \perp \vec r$, we obtain torque magnitude as:
#   $$
#   \tau = r F_t = r a_t m = m r^2 \alpha
#   $$

# %% [markdown]
# ## Revisiting mass vs. mass distribution
#
# `mk14 - Abrollen versch. Körper`
#
# $$\tau = m r^2 \alpha$$
#
# **$\Rightarrow$ mass distribution captured by $m r^2$** **$\Rightarrow$ moment of inertia $I$**

# %% [markdown]
# ## Net torque & moment of inertia
#
# - Moment of inertia $I$ is the **rotational analogue of mass** $\rightarrow$ measures **resistance to changes in rotational motion**.
# - Larger $I$ → smaller angular acceleration for the same torque
#
# - For many particles in a rigid body:
#   $$
#   \tau_{\text{net}} = \sum_i \tau_i = \sum_i m_i r_i^2 \alpha.
#   $$
#   Since all particles share the same $\alpha$, define
#   $$
#   I = \sum_i m_i r_i^2,\qquad
#   \tau_{\text{net}} = I\alpha.
#   $$
#
# - Continuous mass distribution:
#   $$
#   I = \int r^2\,dm.
#   $$
#   $r$ = perpendicular distance from axis to element $dm$.

# %% [markdown]
# ## Net torque & moment of inertia (cont')
#
# `mk23 - torque vs. moment of inertia`
#
# $$
# I = \int r^2\,dm, \qquad
# \tau_{\text{net}} = I\alpha
# $$
#
# - Key idea:
#   Mass farther from the axis contributes **much more** (because of $r^2$).
#
# - Units of $I$: **kg·m²**.
#
# - Rotational equilibrium:
#   If $\vec{\tau}_{\text{net}} = 0$, then $\alpha = 0$ → body at rest or rotating at constant $\omega$.

# %% [markdown]
# ## Moment of inertia: Example
#
# Uniform rod of length $L$, mass $M$, with linear mass density $\lambda = \frac{M}{L}$, rotating about its center:
#
# - Mass element:
#   $$
#   dm = \lambda\, dx = \frac{M}{L}dx.
#   $$
# - Compute $I$:
#   $$
#   I = \frac{M}{L}\int_{-L/2}^{L/2} x^2 dx
#   = \frac{1}{12}ML^2.
#   $$
#
# - Result for rod about its center:
#   $$
#   I_{\text{center}} = \frac{1}{12}ML^2.
#   $$
#
# <img src="../img/from_wiki/Moment_of_inertia_rod_center.svg" alt="Moment_of_inertia_rod_center.svg" width="200"/>
#
# *<sub>from [wikipedia](https://en.wikipedia.org/wiki/File:Moment_of_inertia_rod_center.svg), [CC0 1.0 Universal](https://creativecommons.org/publicdomain/zero/1.0/deed.en)</sub>*

# %% [markdown]
# ## Moment of inertia: Example II
# Uniform rod with $L$, $M$, rotating about one end:
#
# $$
#   I = \frac{M}{L}\int_0^L x^2 dx
#   = \frac{1}{3}ML^2.
# $$
#
# **Interpretation**: Moving the axis away from the center of mass increases $I$
#
# **$\Rightarrow$ Moment of inertia depends on rotation axis**

# %% [markdown]
# ## Parallel-axis Theorem (Steiner's theorem)
#
# - Used when the rotation axis is **shifted** from the center-of-mass (CM) axis.
#
# - Theorem:
#   $$
#   I = I_{\text{CM}} + Md^2,
#   $$
#   with $I_{\text{CM}}$ = moment of inertia about CM axis,$d$ = distance between axes
#
# <img src="../img/from_wiki/Steiner.png" alt="Steiner.png" width="200"/>
#
# *<sub>from [wikipedia](https://en.wikipedia.org/wiki/File:Steiner.png), [Attribution-Share Alike 3.0 Unported](//creativecommons.org/licenses/by-sa/3.0/deed.en)</sub>*

# %% [markdown]
# ## Moment of inertia: Revisit Example II
#
# Uniform rod, length $L$, mass $M$, rotating about one end:
#   $$
#   I_{\text{CM}} = \frac{1}{12}ML^2, \qquad d = \frac{L}{2}.
#   $$
#
# Moment of inertia about end:
#   $$
#   I_{\text{end}}
#   = \frac{1}{12}ML^2 + M\left(\frac{L}{2}\right)^2
#   = \frac{1}{3}ML^2.
#   $$
#
# **Practical note**: Usually easier to start from a known **CM moment of inertia** and apply the **parallel-axis theorem** instead of re-integrating.

# %% [markdown]
# ## Common Moments of Inertia & the Tensor Perspective
#
# <img src="../img/from_wiki/Moment_of_inertia_examples.gif" alt="Moment_of_inertia_examples.gif" width="450"/>
#
# *<sub>from [wikipedia](https://en.wikipedia.org/wiki/File:Moment_of_inertia_examples.gif), public domain</sub>*

# %% [markdown]
# ## Moments of Inertia: Tensor Perspective
#
# - Moment of inertia is an **inertia tensor** in 3D
# - Different axes → different values of $I$
# - In this course: rotation about **one symmetry axis**, so $I$ behaves like a scalar
#
# <img src="../img/from_wiki/Components_stress_tensor.svg" alt="Components_stress_tensor.svg" width="200"/>
# <img src="../img/from_wiki/Tensor_dimensions.svg" alt="Tensor_dimensions.svg" width="300"/>
#
#
# *<sub>[left] **Stress tensor example** from [wikipedia](https://en.wikipedia.org/wiki/File:Components_stress_tensor.svg), [Attribution-Share Alike 3.0 Unported](//creativecommons.org/licenses/by-sa/3.0/deed.en);
# [right] from [wikipedia](https://en.wikipedia.org/wiki/File:Tensor_dimensions.svg), [Attribution-Share Alike 4.0 International](//creativecommons.org/licenses/by-sa/4.0/deed.en)</sub>*

# %% [markdown]
# ##  Rotational Kinetic Energy
#
# - Rotating rigid body:
#     - Treat body as many small masses $m_i$ at distances $r_i$ with velocity $v_i = r_i\omega$
#
#     - Kinetic energy of each element:
#   $$
#   K_i = \tfrac{1}{2} m_i v_i^2 = \tfrac{1}{2} m_i r_i^2 \omega^2.
#   $$
#
# - Total rotational kinetic energy:
#   $$
#   K_{\text{rot}} = \sum_i K_i = \tfrac{1}{2}\omega^2 \sum_i m_i r_i^2.
#   $$
#
# - Recognize the moment of inertia: $I = \sum_i m_i r_i^2$
#
# - Final result:
#   $$
#   K_{\text{rot}} = \tfrac{1}{2}I\omega^2
#   $$
# - Direct analogue of $K_{\text{trans}} = \tfrac{1}{2}mv^2$ with $m \rightarrow I$ and $v \rightarrow \omega$.

# %% [markdown]
# ## Work Done by a Torque: Rotational Work–Energy Theorem
#
#   $$
#   W = \int_{\theta_i}^{\theta_f} \tau\, d\theta.
#   $$
#
# - Using $\tau = I\alpha = I\tfrac{d \omega}{dt} = I\tfrac{d \omega}{d\phi}\tfrac{d \phi}{dt} = I\tfrac{d \omega}{d\phi}\omega$, the net work becomes:
#   $$
#   W = \int_{\theta_i}^{\theta_f} I \frac{d \omega}{d \phi} \, \omega d\phi = I \int_{\theta_i}^{\theta_f}\omega d\omega
#   $$
#
#   $$
#   W_{\text{net}} = \Delta K_{\text{rot}}
#   = \tfrac{1}{2}I\omega_f^2 - \tfrac{1}{2}I\omega_i^2.
#   $$

# %% [markdown]
# ## Rolling Without Slipping
#
# - Rolling = **translation of the center of mass** + **rotation about an axis**.
#
# - No-slip condition: **contact point is instantaneously at rest** relative to the surface
#   $$
#   v_{\text{CM}} - R\omega = 0 \; \leftrightarrow \; v_{\text{CM}} = R\omega \; \leftrightarrow \; a_{\text{CM}} = R\alpha
#   $$
#
# - Interpretation: one full revolution → object advances by $2\pi R$.
#
# - If $v_{\text{CM}} \neq R\omega$ → **slipping**
#
#
# <img src="../img/from_wiki/Rolling_animation.gif" alt="Rolling_animation.gif" width="300"/>
#
# *<sub>from [wikipedia](https://en.wikipedia.org/wiki/File:Rolling_animation.gif), [Attribution-Share Alike 4.0 International](//creativecommons.org/licenses/by-sa/4.0/deed.en)</sub>*

# %% [markdown]
# ##  Flywheel: Storing rotational energy
#
# **stores rotational energy via conservation of angular momentum**
#
# <img src="../img/from_wiki/Schwungrad02.jpg" alt="Schwungrad02.jpg" width="140"/>
# <img src="../img/from_wiki/Lanz_Bulldog_1928-crop.jpg" alt="Lanz_Bulldog_1928-crop.jpg" width="250"/>
#
# *<sub>[left] from [wikipedia](https://de.wikipedia.org/wiki/Datei:Schwungrad02.jpg), [Attribution-Share Alike 3.0 Unported](//creativecommons.org/licenses/by-sa/3.0/deed.de);
# [right] from [wikipedia](https://de.wikipedia.org/wiki/Datei:Lanz_Bulldog_1928-crop.jpg), [Attribution-Share Alike 3.0 Unported](//creativecommons.org/licenses/by-sa/3.0/deed.de)</sub>*

# %% [markdown]
# ## Angular momentum for a Particle
#
# - **angular momentum** $\vec{L}$ (linear analogue $\vec{p} = m\vec{v}$):
# $$ \vec L = \vec r \times  \vec p = \vec r \times  m \vec v$$
#
# - Angular momentum is a **vector** (axial/pseudovector) with direction from the **right-hand rule**
# - Units: **kg·m²/s**
#
# - Magnitude:
# $$L = r p \sin\phi = r m v \sin\phi$$
# - For particle in circular motion with $v = r\omega$ and $I = mr^2$:
# $$
# L = mrv = mr(r\omega) = mr^2\omega = I\omega
# $$
#
#
# <img src="../img/from_wiki/Torque_animation.gif" alt="Torque_animation.gif" width="300"/>
#
# *<sub>from [wikipedia](https://en.wikipedia.org/wiki/File:Torque_animation.gif), public domain</sub>*

# %% [markdown]
# ## Angular momentum for a Particle (cont')
#
# $$ \vec L = \vec r \times  \vec p$$
#
#
# - Time derivative (product rule):
#   $$
#   \frac{d\vec{L}}{dt}
#   = \frac{d\vec{r}}{dt} \times \vec{p}
#     + \vec{r} \times \frac{d\vec{p}}{dt}
#   $$
#
# - Substitute $\frac{d\vec{r}}{dt} = \vec{v}$, $\vec{p} = m\vec{v}$, and $\vec{F} = \frac{d\vec{p}}{dt}$:
#   - First term: $\vec{v} \times m\vec{v} = \vec{0}$ (parallel vectors).
#   - Remaining term:
#     $$
#     \frac{d\vec{L}}{dt} = \vec{r} \times \vec{F} = \vec{\tau}
#     $$
#
# - Analogue relation to translational dynamics:
#   $$
#   \vec{\tau} = \frac{d\vec{L}}{dt} \; \leftrightarrow \; \vec{F} = \frac{d\vec{p}}{dt}
#   $$

# %% [markdown]
# ## Angular momentum for a Rigid Object
#
#   $$
#   \vec{L} = I\vec{\omega}
#   $$
#
# - Differentiate (rigid body → $I$ constant):
#   $$
#   \frac{d\vec{L}}{dt} = \frac{I d\vec{\omega}}{dt} = I\vec{\alpha}.
#   $$
#   Therefore:
#   $$
#   \vec{\tau}_{\text{net}} = I\vec{\alpha}.
#   $$
#   Rotational analogue of $F = ma$.

# %% [markdown]
# ##  Angular Momentum Summary:
#   - Particles: $\vec{L} = \vec{r} \times \vec{p}$
#   - Rigid bodies: $\vec{L} = I\vec{\omega}$ (for symmetry axes)
#   - Always:
#     $$
#     \vec{\tau}_{\text{ext}} = \frac{d\vec{L}}{dt}
#     $$

# %% [markdown]
# ## Conservation of Angular Momentum - Theory
# - If net external torque is zero:
#   $$
#   \frac{d\vec{L}}{dt} = 0 \; \leftrightarrow \; \vec L = \text{const.}
#   $$
# - **If the net external torque is zero, angular momentum stays constant**
#
# - Internal mass redistribution can change angular velocities, **but not total angular momentum**
#
# - Applies to all scales: atoms, planets, stars, skaters, rotating machinery, etc

# %% [markdown]
# ## Conservation of Angular Momentum - Seeing is believing
#
# `mk13 - Drehimpulserhaltung`
#
# - For rotation about a fixed axis (direction of $\vec{L}$ unchanged):
#   $$
#   L_1 = L_2, \qquad I_1\omega_1 = I_2\omega_2
#   $$

# %% [markdown]
# ## Conservation of Angular Momentum - Key points
#
# - Angular momentum is conserved when the **net external torque** is zero.
# - Internal forces cannot change total $\vec{L}$, only its distribution.
# - Reducing moment of inertia increases angular velocity if $L$ is fixed.
# - Conservation applies at all scales: atoms, machinery, stars, galaxies.
# - When torque-free, both the **magnitude** and **direction** of $\vec{L}$ remain constant.
# - Collisions or mass redistribution obey angular momentum conservation when isolated from external torques.

# %% [markdown]
# <img src="../img/Signet_FNW_1.svg" alt="OVGU_FNW_Logo" width="300" align="right">
#
# ## Solve initial question
#
# `mk15`
#
# `Tasche mit Wasser und Papierschnipsel`
#
# **Which egg is cooked? How to check?**

# %% [markdown]
# ## Bonus Puzzle
#
# `mk11 - Maxwellsches Rad`
#
# **How can the scale show less weight?**

# %% [markdown]
# $$\tau = T r = I \alpha$$
#
# $$m a = m g - T  \; \leftrightarrow \; T = m (g-a)$$
#
# $$\Rightarrow a < g$$
